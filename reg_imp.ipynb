# %%
from google import genai

client = genai.Client(api_key="")

session = client.chats.create(model="gemini-2.5-flash")
response = session.send_message("Explain how AI works")
print(response.text)
# Out:
# Artificial Intelligence (AI) isn't a single magical entity but rather a broad field of computer science focused on creating machines that can perform tasks typically requiring human intelligence.
#
# At its core, **AI works by enabling machines to learn from data, identify patterns, make decisions, and solve problems without being explicitly programmed for every single scenario.**
#
# Let's break down the fundamental principles and common approaches:
#
# ---
#
# ### The Core Idea: Learning from Data
#
# Imagine teaching a child to recognize a cat.
# 1.  **You show them many pictures of cats** (data).
# 2.  **You point out features** (ears, whiskers, tail, fur).
# 3.  **You tell them "This is a cat."** (labeling/feedback).
# 4.  **They start to form an internal "model"** of what a cat looks like.
# 5.  **When they see a new animal, they apply their model** and say "cat!" or "dog!"
#
# AI works in a very similar way, but with algorithms and massive amounts of data.
#
# ---
#
# ...

# %%
response = session.send_message("Explain the above content like you do to 5 year old ")

# %%
print(response.text)
# Out:
# Okay, imagine you have a super smart robot friend, like a teddy bear that can learn!
#
# **AI is like teaching your robot friend to be super smart and help you.**
#
# How does your robot friend learn?
#
# 1.  **Showing and Telling (Like Mommy or Daddy Teaching You):**
#     *   Imagine you want your robot friend to know what a cat is.
#     *   You show it *lots and lots* of pictures of cats and you say, "MEOW! This is a cat!" every time.
#     *   After seeing many cats, your robot friend learns what a cat looks like. Then, when it sees a *new* picture, it can say, "Hey! That's a cat!" all by itself!
#     *   *This is how AI learns to tell cats from dogs, or find bad emails (called spam), or know when you're smiling in a picture.*
#
# 2.  **Sorting Things Out (Like You Sorting Your Toys):**
#     *   Sometimes, you give your robot friend a big pile of toys – cars, blocks, dolls – and you don't tell it what they are.
# ...

# %%
ans = session.send_message("What do you mean by showing and teling ")

# %%
print(ans.text)
# Out:
# Okay, let's pretend again!
#
# "Showing and telling" is just like when Mommy or Daddy teaches you something new!
#
# Imagine you're learning about colors:
#
# 1.  **Showing:** Mommy holds up a bright red apple.
# 2.  **Telling:** She says, "This is **RED**!"
#
# Then she does it again!
#
# 1.  **Showing:** She holds up a red ball.
# 2.  **Telling:** She says, "This is **RED**!"
#
# And again with a red car!
#
# 1.  **Showing:** A little red toy car.
# 2.  **Telling:** "This is **RED**!"
#
# After she **shows** you many different red things and **tells** you "RED" every time, your super smart little brain learns what "RED" means!
#
# Then, when you see a *new* red thing, you can say, "Hey! That's RED!" all by yourself!
#
# **So, for our robot friend:**
#
# *   **Showing** means giving it a picture or a sound or some words.
# ...

# %%
# Ingestion, Embedding, Vectorstore (pgvector), Retrieval (top k, similarity), Augmented, Generation

# %%
from google import genai

client = genai.Client(api_key="")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
